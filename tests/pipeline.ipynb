# %%
import sys
import tensorflow as tf
sys.path.append('../src')

from data_loading import BavarianBuildingDataset
from mask_rcnn import MaskRCNN

# %%
dataset = BavarianBuildingDataset(image_dir='../data/bbd250-image', mask_dir='../data/bbd250-umring')

# %%
maskRCNN = MaskRCNN()
maskRCNN.model.summary()
# Out:
# Model: "Mask_RCNN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(8, 250, 250, 3)]   0           []
#
#  Backbone (Functional)          (8, 8, 8, 2048)      23587712    ['input_image[0][0]']
#
#  RPN (Functional)               (8, None, 4)         9601856     ['Backbone[0][0]']
#
#  ROI_Align (Functional)         (8, None, 7, 7, 204  0           ['Backbone[0][0]',
#                                 8)                                'RPN[0][0]']
#
# ==================================================================================================
# Total params: 33,189,568
# Trainable params: 9,605,952
# Non-trainable params: 23,583,616
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(maskRCNN.model, show_shapes=True, show_layer_names=True, to_file='../model/model_structure.png')
